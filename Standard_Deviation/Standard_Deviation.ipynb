# %% [markdown]
# <a href="https://colab.research.google.com/github/adrikagupta/Maths-for-Data-Science/blob/main/Standard_Deviation/Standard_Deviation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mean Absolute Deviation
# We are trying to learn how far apart the individual data points are from the average or how spread out the data points are with respect to average.
# <br>
# To represent this we use - MAD - take difference of individual score with respect to avergage , sum it and then take average
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There could be scenario MAD is same
# <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Standard Deviation
#
# square of (score - avg) -> avg -> sqrt because we squared the numbers individually
# <br>
# ![image.png](data:image/png;base64,...)

# %%
L1 norm - MAD
L2 norm - SD
